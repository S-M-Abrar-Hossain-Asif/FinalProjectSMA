# %% [markdown]
# ## Social Media Analytics
#
# # Webscraping Project
# ## Introduction to Text Mining
# ## Preprocessing
#
#
# ##### Felix Funes 20220306 | Paula Catalan 20221048 | Efstathia Styliagkatzi 20220078 | Alisson Tapia 20221156 | S M Abrar Hossain Asif 20220223

# %% [markdown]
# After extracting the necessary data we believe was relevant for the purpose of this project.  It is time for data preprocessing which involves cleaning and transforming the data obtained from best buy web pages before it can be analyzed.
#
#
# Some of the importan reason of pre-process our data are:
#
# *  Data Quality: Web pages are often unstructured, messy and noisy, which makes it challenging to extract clean and accurate data. Data preprocessing helps to clean and filter out irrelevant or inaccurate data, so that only the useful information is retained.
#
# *  Data Consistency: Data from web pages can come in different formats, with varying levels of detail and granularity. Data preprocessing helps to standardize the data format, so that it can be easily compared and analyzed across different web pages.
#
# * Data Integration: Data collected from web scraping is often stored in different formats or data sources, which makes it difficult to combine and integrate. Data preprocessing helps to transform and merge the data into a consistent format that can be easily combined and integrated with other data sources.
#
# *  Efficiency: Preprocessing can also help to optimize the data processing pipeline by reducing the amount of data that needs to be processed, and by optimizing the data format for efficient storage and retrieval.
#
# * Accuracy: Preprocessing can also help to reduce errors and inconsistencies that can arise from incomplete, missing or incorrect data, which can lead to inaccurate analysis and decision-making.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
nltk.download()
import csv
import pandas as pd
import numpy as np
import nltk 
from bs4 import BeautifulSoup
import re
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\madel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\madel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\madel\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\madel\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
# Load dataset
dtypes = {'device':'category','user':'category','rating':'integer','ownership_lenght':'category'}
reviews_to_clean = pd.read_excel("ExtractedReviewsDataCollection1.xlsx", sheet_name="Sheet1", index_col = 'user', engine='openpyxl')
reviews_to_clean = reviews_to_clean.drop(reviews_to_clean.columns[0], axis=1)

# %%
# Check first rows
reviews_to_clean.head()
# Out:
#                                                     device  rating  \
# user
# BigG          Apple - iPhone 14 128GB - Midnight (Verizon)       5
# Jp44087       Apple - iPhone 14 128GB - Midnight (Verizon)       5
# GamerDadLife  Apple - iPhone 14 128GB - Midnight (Verizon)       5
# LevanaP       Apple - iPhone 14 128GB - Midnight (Verizon)       5
# Anonymous     Apple - iPhone 14 128GB - Midnight (Verizon)       5
#
#                                                            text       date  \
# user
# BigG          Apple makes the best cellphone on the market h... 2023-02-03
# Jp44087       Ease of use, good battery life, 128gb fits me ... 2023-02-03
# GamerDadLife  Love it works great and the red color is the m... 2022-12-24
# LevanaP       Been a long time iPhone user. This is a awesom... 2023-04-14
# Anonymous     My wife dropped her phone right AFTER the Appl... 2023-04-15
#
#               ownership_length
# user
# BigG          less than 1 week
# Jp44087                3 weeks
# GamerDadLife           2 weeks
# LevanaP                 1 week
# Anonymous              3 weeks

# %%
# Describe dataset
summary=reviews_to_clean.describe(include='all')
summary=summary.transpose()
summary.head(len(summary))
# Out:
# C:\Users\madel\AppData\Local\Temp\ipykernel_18580\2217404966.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   summary=reviews_to_clean.describe(include='all')
#                   count unique  \
# device              373      8
# rating            373.0    NaN
# text                373    369
# date                373    130
# ownership_length    373     10
#
#                                                                 top freq  \
# device                 Apple - iPhone 14 128GB - Midnight (Verizon)  112
# rating                                                          NaN  NaN
# text              Apple makes the best cellphone on the market h...    2
# date                                            2022-12-02 00:00:00   15
# ownership_length                                             1 week  109
#
#                       first       last      mean       std  min  25%  50%  \
# device                  NaT        NaT       NaN       NaN  NaN  NaN  NaN
# rating                  NaT        NaT  4.702413  0.775928  1.0  5.0  5.0
# text                    NaT        NaT       NaN       NaN  NaN  NaN  NaN
# date             2022-09-17 2023-04-21       NaN       NaN  NaN  NaN  NaN
# ownership_length        NaT        NaT       NaN       NaN  NaN  NaN  NaN
#
#                   75%  max
# device            NaN  NaN
# rating            5.0  5.0
# text              NaN  NaN
# date              NaN  NaN
# ownership_length  NaN  NaN

# %%
# View text of review 
reviews = reviews_to_clean['text']
reviews = reviews.tolist()
# print the first 5 reviews for verification purposes
print("All review:\n", reviews)
# Out:
# All review:
#  ['Apple makes the best cellphone on the market hands down', 'Ease of use, good battery life, 128gb fits me just fine', 'Love it works great and the red color is the most gorgeous iPhone color ever', 'Been a long time iPhone user. This is a awesome phone. Full size screen, much faster & so many ways to customize!!! I love it!', 'My wife dropped her phone right AFTER the Apple protect plan expired.', 'Liked the color but the otterbox covers most of the color', 'The perfect iPhone! this thing is amazing for anyone in the family! Kids or Grandma! or anyone else! super powerful, you can run a business off of it!', 'We were going to purchase iPhones through Verizon but when we stopped by Best Buy which I have 0% finance through Best Buy and the person who has excellent knowledge and started to finish assisted all the way. my husband and I were very much satisfied and glad to shop at best buy', 'So far, so good. I used android since I got a cellphone 30 years ago. What a difference!! Easy to learn how to use for a senior population member. I highly recommend. I was afraid of the smaller keyboard. No problem!!', "the phone is pretty - I just don't like when shutting the screen down the side buttons on each side get pressed together when trying to just press the one and then a picture is taken - also the button to silence the phone is hard for my finger to reach in to move it", 'Long overdue upgrade from iPhone 7 to 14. Totally worth it, especially when adding a Verizon plan upgrade (that actually reduced our monthly cost) and the 0% financing and Best Buy incentives.', 'Great keep it up please received as said unlike other we keep getting cancelled after confirmation', "new to Iphone - had a droid - so trying to navigate through everything is a challenge - having issues with group texts I'm not receiving them all - did shut the phone down and restarted and the texts still did not show up", 'I waited a month before entering this review-very pleased with the iPhone 14 and just as happy with the service. They had all of the data transferred within 15 minutes and I was up and running>', 'I don’t upgrade my phone frequently.  I went from the 7 to the 14.   A big jump!  It appears to do what I need it to do but there is probably a lot more I could learn about it and it’s features. I was hooked on the Home button!  The  loss of it makes the frame a little smaller and phone seems much lighter.   All the ‘swiping’ definitely takes some getting used to.', 'Product follows design and functionality of previous generations of iPhones.', 'This phone is GREAT!  an upgrade for son who was on a SLOW iphone 11.  Three years is about the most for a battery.  Sure wish apple would allow easy battery changes', 'new i phones work great.  this is the best device for the money', 'Daughter needed a new phone as her xr was not working. This is a bit smaller which she liked with more memory. Disappointed the charging block not included but that is an apple issue. Otherwise, working well. Set up in the store was great!', 'I upgraded from 6s to 14 and scratch my head why I haven’t been upgrading along the way. It is night and day', 'Great Value and couldn’t pass on the carrier deals for my moms old Samsung Galaxy S7.\n\nI personally am more a pro iPhone kind of guy, but at $799, you can’t beat what the phone offers.', 'After seeing this product i realized that i wanted a bigger size the phone was great and useful but i need something a little better', 'Always love Apple products and this phone does not disappoint. Color is gorgeous, display is so crisp and clear! Great upgrades to the camera as well.', 'Best phone EVERRRRRRRRRRRR. It’s perfect Apple should just grow off this phone because it has no flaws', 'Easy to use and not very much larger than my old phone.', 'As always apple products exceed expectations. I’m committed to the Apple family line of products.', 'Needed an upgrade, so I went with the iPhone, price was reasonable and I really like the color.', ' ...

# %%
# Removing the HTML tags from the text using BeautifulSoup 
rawtext = [BeautifulSoup(review, 'html.parser').get_text() for review in reviews]

# print the first 5 cleaned reviews for verification purposes
print(' All review without HTML:\n' , rawtext)
# Out:
#  All review without HTML:
#  ['Apple makes the best cellphone on the market hands down', 'Ease of use, good battery life, 128gb fits me just fine', 'Love it works great and the red color is the most gorgeous iPhone color ever', 'Been a long time iPhone user. This is a awesome phone. Full size screen, much faster & so many ways to customize!!! I love it!', 'My wife dropped her phone right AFTER the Apple protect plan expired.', 'Liked the color but the otterbox covers most of the color', 'The perfect iPhone! this thing is amazing for anyone in the family! Kids or Grandma! or anyone else! super powerful, you can run a business off of it!', 'We were going to purchase iPhones through Verizon but when we stopped by Best Buy which I have 0% finance through Best Buy and the person who has excellent knowledge and started to finish assisted all the way. my husband and I were very much satisfied and glad to shop at best buy', 'So far, so good. I used android since I got a cellphone 30 years ago. What a difference!! Easy to learn how to use for a senior population member. I highly recommend. I was afraid of the smaller keyboard. No problem!!', "the phone is pretty - I just don't like when shutting the screen down the side buttons on each side get pressed together when trying to just press the one and then a picture is taken - also the button to silence the phone is hard for my finger to reach in to move it", 'Long overdue upgrade from iPhone 7 to 14. Totally worth it, especially when adding a Verizon plan upgrade (that actually reduced our monthly cost) and the 0% financing and Best Buy incentives.', 'Great keep it up please received as said unlike other we keep getting cancelled after confirmation', "new to Iphone - had a droid - so trying to navigate through everything is a challenge - having issues with group texts I'm not receiving them all - did shut the phone down and restarted and the texts still did not show up", 'I waited a month before entering this review-very pleased with the iPhone 14 and just as happy with the service. They had all of the data transferred within 15 minutes and I was up and running>', 'I don’t upgrade my phone frequently.  I went from the 7 to the 14.   A big jump!  It appears to do what I need it to do but there is probably a lot more I could learn about it and it’s features. I was hooked on the Home button!  The  loss of it makes the frame a little smaller and phone seems much lighter.   All the ‘swiping’ definitely takes some getting used to.', 'Product follows design and functionality of previous generations of iPhones.', 'This phone is GREAT!  an upgrade for son who was on a SLOW iphone 11.  Three years is about the most for a battery.  Sure wish apple would allow easy battery changes', 'new i phones work great.  this is the best device for the money', 'Daughter needed a new phone as her xr was not working. This is a bit smaller which she liked with more memory. Disappointed the charging block not included but that is an apple issue. Otherwise, working well. Set up in the store was great!', 'I upgraded from 6s to 14 and scratch my head why I haven’t been upgrading along the way. It is night and day', 'Great Value and couldn’t pass on the carrier deals for my moms old Samsung Galaxy S7.\n\nI personally am more a pro iPhone kind of guy, but at $799, you can’t beat what the phone offers.', 'After seeing this product i realized that i wanted a bigger size the phone was great and useful but i need something a little better', 'Always love Apple products and this phone does not disappoint. Color is gorgeous, display is so crisp and clear! Great upgrades to the camera as well.', 'Best phone EVERRRRRRRRRRRR. It’s perfect Apple should just grow off this phone because it has no flaws', 'Easy to use and not very much larger than my old phone.', 'As always apple products exceed expectations. I’m committed to the Apple family line of products.', 'Needed an upgrade, so I went with the iPhone, price was reasonable and I really like the color.', ' ...

# %%
# Normalize case
# The typical is normalizing to lower case
normalizedText = [review.lower() for review in rawtext]
print("Normalized text:\n", normalizedText[0:10])
# Out:
# Normalized text:
#  ['apple makes the best cellphone on the market hands down', 'ease of use, good battery life, 128gb fits me just fine', 'love it works great and the red color is the most gorgeous iphone color ever', 'been a long time iphone user. this is a awesome phone. full size screen, much faster & so many ways to customize!!! i love it!', 'my wife dropped her phone right after the apple protect plan expired.', 'liked the color but the otterbox covers most of the color', 'the perfect iphone! this thing is amazing for anyone in the family! kids or grandma! or anyone else! super powerful, you can run a business off of it!', 'we were going to purchase iphones through verizon but when we stopped by best buy which i have 0% finance through best buy and the person who has excellent knowledge and started to finish assisted all the way. my husband and i were very much satisfied and glad to shop at best buy', 'so far, so good. i used android since i got a cellphone 30 years ago. what a difference!! easy to learn how to use for a senior population member. i highly recommend. i was afraid of the smaller keyboard. no problem!!', "the phone is pretty - i just don't like when shutting the screen down the side buttons on each side get pressed together when trying to just press the one and then a picture is taken - also the button to silence the phone is hard for my finger to reach in to move it"]

# %%
# Remove punctation and other characters such as "&"
charsToRemove = r"\?|\.|\!|\;|\.|\"|\,|\(|\)|\&|[0-9]"
textWOPunctuation = [re.sub(charsToRemove, '', review) for review in normalizedText]
print("Text without punctuation:\n",textWOPunctuation[0:10])
# Out:
# Text without punctuation:
#  ['apple makes the best cellphone on the market hands down', 'ease of use good battery life gb fits me just fine', 'love it works great and the red color is the most gorgeous iphone color ever', 'been a long time iphone user this is a awesome phone full size screen much faster  so many ways to customize i love it', 'my wife dropped her phone right after the apple protect plan expired', 'liked the color but the otterbox covers most of the color', 'the perfect iphone this thing is amazing for anyone in the family kids or grandma or anyone else super powerful you can run a business off of it', 'we were going to purchase iphones through verizon but when we stopped by best buy which i have % finance through best buy and the person who has excellent knowledge and started to finish assisted all the way my husband and i were very much satisfied and glad to shop at best buy', 'so far so good i used android since i got a cellphone  years ago what a difference easy to learn how to use for a senior population member i highly recommend i was afraid of the smaller keyboard no problem', "the phone is pretty - i just don't like when shutting the screen down the side buttons on each side get pressed together when trying to just press the one and then a picture is taken - also the button to silence the phone is hard for my finger to reach in to move it"]

# %%
stop_words = set(stopwords.words('english'))
print (stop_words)
# Out:
# {"won't", 'd', 'that', 'into', "isn't", 'be', 'don', 'this', 'down', 'yourselves', 'any', 'herself', "you'll", 'won', 'those', "didn't", 'or', 'between', 'didn', 'not', 'out', 'ourselves', 'will', 'over', "it's", "haven't", 'all', 'because', "she's", 've', 'a', 'her', 'its', 'o', 'should', 'itself', 'against', 'below', "wasn't", 'why', 'being', 'when', 'does', 'his', 'own', 'too', 'hers', "mightn't", "you've", 'is', 't', "shan't", 'doesn', 'some', 'it', 'each', 'of', 're', 'couldn', 'same', 'theirs', 'my', 'whom', 'yourself', 'until', 'll', 'only', 'who', 'had', 'after', 'we', 'himself', 'an', 'and', 'having', 'few', 'how', 'ain', 'needn', 'ours', 'in', "aren't", 'there', "mustn't", 'can', 'has', "don't", 'now', 'further', 'myself', 'with', 'hasn', 'if', 'off', 'hadn', 'yours', 'where', 'have', "shouldn't", 'they', 'me', 'here', 'under', 'your', 'such', 'themselves', 'than', 'am', 'the', 'them', 'i', 'y', "hasn't", 'was', 'mustn', 'by', 'these', 'once', 'just', 'wouldn', "you're", 'no', 'more', 'which', 'she', 'doing', 'haven', 'most', 'you', 'did', 'through', 'shouldn', 'were', 'isn', 'before', 'again', "that'll", 'but', 'on', "should've", 'are', 'while', 'up', 'other', 'ma', 'about', "doesn't", 'm', "couldn't", 'wasn', 'for', 'nor', 'our', 'aren', "weren't", 'what', 'as', 's', 'both', 'above', 'at', "wouldn't", 'him', 'very', 'so', 'he', "needn't", 'to', 'from', "hadn't", 'mightn', 'do', 'during', "you'd", 'their', 'been', 'weren', 'then', 'shan'}

# %%
# First, we need to tokenize text - Break it into words
from nltk.tokenize import word_tokenize
text = ''.join(textWOPunctuation)
tokenizedText = word_tokenize(text)

print("List of words:\n",tokenizedText)
# Out:
# List of words:
#  ['apple', 'makes', 'the', 'best', 'cellphone', 'on', 'the', 'market', 'hands', 'downease', 'of', 'use', 'good', 'battery', 'life', 'gb', 'fits', 'me', 'just', 'finelove', 'it', 'works', 'great', 'and', 'the', 'red', 'color', 'is', 'the', 'most', 'gorgeous', 'iphone', 'color', 'everbeen', 'a', 'long', 'time', 'iphone', 'user', 'this', 'is', 'a', 'awesome', 'phone', 'full', 'size', 'screen', 'much', 'faster', 'so', 'many', 'ways', 'to', 'customize', 'i', 'love', 'itmy', 'wife', 'dropped', 'her', 'phone', 'right', 'after', 'the', 'apple', 'protect', 'plan', 'expiredliked', 'the', 'color', 'but', 'the', 'otterbox', 'covers', 'most', 'of', 'the', 'colorthe', 'perfect', 'iphone', 'this', 'thing', 'is', 'amazing', 'for', 'anyone', 'in', 'the', 'family', 'kids', 'or', 'grandma', 'or', 'anyone', 'else', 'super', 'powerful', 'you', 'can', 'run', 'a', 'business', 'off', 'of', 'itwe', 'were', 'going', 'to', 'purchase', 'iphones', 'through', 'verizon', 'but', 'when', 'we', 'stopped', 'by', 'best', 'buy', 'which', 'i', 'have', '%', 'finance', 'through', 'best', 'buy', 'and', 'the', 'person', 'who', 'has', 'excellent', 'knowledge', 'and', 'started', 'to', 'finish', 'assisted', 'all', 'the', 'way', 'my', 'husband', 'and', 'i', 'were', 'very', 'much', 'satisfied', 'and', 'glad', 'to', 'shop', 'at', 'best', 'buyso', 'far', 'so', 'good', 'i', 'used', 'android', 'since', 'i', 'got', 'a', 'cellphone', 'years', 'ago', 'what', 'a', 'difference', 'easy', 'to', 'learn', 'how', 'to', 'use', 'for', 'a', 'senior', 'population', 'member', 'i', 'highly', 'recommend', 'i', 'was', 'afraid', 'of', 'the', 'smaller', 'keyboard', 'no', 'problemthe', 'phone', 'is', 'pretty', '-', 'i', 'just', 'do', "n't", 'like', 'when', 'shutting', 'the', 'screen', 'down', 'the', 'side', 'buttons', 'on', 'each', 'side', 'get', 'pressed', 'together', 'when', 'trying', 'to', 'just', 'press', 'the', 'one', 'and', 'then', 'a', 'picture', 'is', 'taken', '-', 'also', 'the', 'button', 'to', 'silence', 'the', 'phone', 'is', 'hard', 'for', 'my', 'finger', 'to', 'reach', 'in', 'to', 'move', 'itlong', 'overdue', 'upgrade', 'from', 'iphone', 'to', 'totally', 'worth', 'it', 'especially', 'when', 'adding', 'a', 'verizon', 'plan', 'upgrade', 'that', 'actually', 'reduced', 'our', 'monthly', 'cost', 'and', 'the', '%', 'financing', 'and', 'best', 'buy', 'incentivesgreat', 'keep', 'it', 'up', 'please', 'received', 'as', 'said', 'unlike', 'other', 'we', 'keep', 'getting', 'cancelled', 'after', 'confirmationnew', 'to', 'iphone', '-', 'had', 'a', 'droid', '-', 'so', 'trying', 'to', 'navigate', 'through', 'everything', 'is', 'a', 'challenge', '-', 'having', 'issues', 'with', 'group', 'texts', 'i', "'m", 'not', 'receiving', 'them', 'all', '-', 'did', 'shut', 'the', 'phone', 'down', 'and', 'restarted', 'and', 'the', 'texts', 'still', 'did', 'not', 'show', 'upi', 'waited', 'a', 'month', 'before', 'entering', 'this', 'review-very', 'pleased', 'with', 'the', 'iphone', 'and', 'just', 'as', 'happy', 'with', 'the', 'service', 'they', 'had', 'all', 'of', 'the', 'data', 'transferred', 'within', 'minutes', 'and', 'i', 'was', 'up', 'and', 'running', '>', 'i', 'don', '’', 't', 'upgrade', 'my', 'phone', 'frequently', 'i', 'went', 'from', 'the', 'to', 'the', 'a', 'big', 'jump', 'it', 'appears', 'to', 'do', 'what', 'i', 'need', 'it', 'to', 'do', 'but', 'there', 'is', 'probably', 'a', 'lot', 'more', 'i', 'could', 'learn', 'about', 'it', 'and', 'it', '’', 's', 'features', 'i', 'was', 'hooked', 'on', 'the', 'home', 'button', 'the', 'loss', 'of', 'it', 'makes', 'the', 'frame', 'a', 'little', 'smaller', 'and', 'phone', 'seems', 'much', 'lighter', 'all', 'the', '‘', 'swiping', '’', 'definitely', 'takes', 'some', 'getting', 'used', 'toproduct', 'follows', 'design', 'and', 'functionality', 'of', 'previous', 'generations', 'of', 'iphonesthis', 'phone', 'is', 'great', 'an', 'upgrade', 'for', 'son', 'who', 'was', 'on', 'a', 'slow', 'iphone', 'three', 'years', 'is', 'about', 'the', 'most', 'for', 'a', 'battery', 'sure', 'wish', ...

# %%
# Let's create a list with all words that are not part of the stop words list
cleanedText = []
for t in tokenizedText:
    if t not in stop_words:
        cleanedText.append(t)
print("Text without stopwords:\n", cleanedText)
# Out:
# Text without stopwords:
#  ['apple', 'makes', 'best', 'cellphone', 'market', 'hands', 'downease', 'use', 'good', 'battery', 'life', 'gb', 'fits', 'finelove', 'works', 'great', 'red', 'color', 'gorgeous', 'iphone', 'color', 'everbeen', 'long', 'time', 'iphone', 'user', 'awesome', 'phone', 'full', 'size', 'screen', 'much', 'faster', 'many', 'ways', 'customize', 'love', 'itmy', 'wife', 'dropped', 'phone', 'right', 'apple', 'protect', 'plan', 'expiredliked', 'color', 'otterbox', 'covers', 'colorthe', 'perfect', 'iphone', 'thing', 'amazing', 'anyone', 'family', 'kids', 'grandma', 'anyone', 'else', 'super', 'powerful', 'run', 'business', 'itwe', 'going', 'purchase', 'iphones', 'verizon', 'stopped', 'best', 'buy', '%', 'finance', 'best', 'buy', 'person', 'excellent', 'knowledge', 'started', 'finish', 'assisted', 'way', 'husband', 'much', 'satisfied', 'glad', 'shop', 'best', 'buyso', 'far', 'good', 'used', 'android', 'since', 'got', 'cellphone', 'years', 'ago', 'difference', 'easy', 'learn', 'use', 'senior', 'population', 'member', 'highly', 'recommend', 'afraid', 'smaller', 'keyboard', 'problemthe', 'phone', 'pretty', '-', "n't", 'like', 'shutting', 'screen', 'side', 'buttons', 'side', 'get', 'pressed', 'together', 'trying', 'press', 'one', 'picture', 'taken', '-', 'also', 'button', 'silence', 'phone', 'hard', 'finger', 'reach', 'move', 'itlong', 'overdue', 'upgrade', 'iphone', 'totally', 'worth', 'especially', 'adding', 'verizon', 'plan', 'upgrade', 'actually', 'reduced', 'monthly', 'cost', '%', 'financing', 'best', 'buy', 'incentivesgreat', 'keep', 'please', 'received', 'said', 'unlike', 'keep', 'getting', 'cancelled', 'confirmationnew', 'iphone', '-', 'droid', '-', 'trying', 'navigate', 'everything', 'challenge', '-', 'issues', 'group', 'texts', "'m", 'receiving', '-', 'shut', 'phone', 'restarted', 'texts', 'still', 'show', 'upi', 'waited', 'month', 'entering', 'review-very', 'pleased', 'iphone', 'happy', 'service', 'data', 'transferred', 'within', 'minutes', 'running', '>', '’', 'upgrade', 'phone', 'frequently', 'went', 'big', 'jump', 'appears', 'need', 'probably', 'lot', 'could', 'learn', '’', 'features', 'hooked', 'home', 'button', 'loss', 'makes', 'frame', 'little', 'smaller', 'phone', 'seems', 'much', 'lighter', '‘', 'swiping', '’', 'definitely', 'takes', 'getting', 'used', 'toproduct', 'follows', 'design', 'functionality', 'previous', 'generations', 'iphonesthis', 'phone', 'great', 'upgrade', 'son', 'slow', 'iphone', 'three', 'years', 'battery', 'sure', 'wish', 'apple', 'would', 'allow', 'easy', 'battery', 'changesnew', 'phones', 'work', 'great', 'best', 'device', 'moneydaughter', 'needed', 'new', 'phone', 'xr', 'working', 'bit', 'smaller', 'liked', 'memory', 'disappointed', 'charging', 'block', 'included', 'apple', 'issue', 'otherwise', 'working', 'well', 'set', 'store', 'greati', 'upgraded', 'scratch', 'head', '’', 'upgrading', 'along', 'way', 'night', 'daygreat', 'value', '’', 'pass', 'carrier', 'deals', 'moms', 'old', 'samsung', 'galaxy', 'personally', 'pro', 'iphone', 'kind', 'guy', '$', '’', 'beat', 'phone', 'offersafter', 'seeing', 'product', 'realized', 'wanted', 'bigger', 'size', 'phone', 'great', 'useful', 'need', 'something', 'little', 'betteralways', 'love', 'apple', 'products', 'phone', 'disappoint', 'color', 'gorgeous', 'display', 'crisp', 'clear', 'great', 'upgrades', 'camera', 'wellbest', 'phone', 'everrrrrrrrrrrr', '’', 'perfect', 'apple', 'grow', 'phone', 'flawseasy', 'use', 'much', 'larger', 'old', 'phoneas', 'always', 'apple', 'products', 'exceed', 'expectations', '’', 'committed', 'apple', 'family', 'line', 'productsneeded', 'upgrade', 'went', 'iphone', 'price', 'reasonable', 'really', 'like', 'colorthe', 'phone', 'real', 'nice', 'associate', 'transaction', 'goodpurchased', 'phone', 'son', 'said', 'awesome', 'way', 'better', 'iphone', 'xr', 'previously', 'usingbest', 'phones', 'really', 'appreciate', 'new', 'style', 'old', 'styleapple', 'makes', 'best', 'cellphone', 'market', 'hands', 'downas', 'expected', 'high-quality', 'produc ...

# %%
# Now, let's concatenate it again to a sentence
newText = ''
for t in cleanedText:
  newText = newText + t + ' '
newText = newText.rstrip() # rstring (remove spaces at the right of the string)
print("Full sentence with changes so far:\n", newText)
# Out:
# Full sentence with changes so far:
#  apple makes best cellphone market hands downease use good battery life gb fits finelove works great red color gorgeous iphone color everbeen long time iphone user awesome phone full size screen much faster many ways customize love itmy wife dropped phone right apple protect plan expiredliked color otterbox covers colorthe perfect iphone thing amazing anyone family kids grandma anyone else super powerful run business itwe going purchase iphones verizon stopped best buy % finance best buy person excellent knowledge started finish assisted way husband much satisfied glad shop best buyso far good used android since got cellphone years ago difference easy learn use senior population member highly recommend afraid smaller keyboard problemthe phone pretty - n't like shutting screen side buttons side get pressed together trying press one picture taken - also button silence phone hard finger reach move itlong overdue upgrade iphone totally worth especially adding verizon plan upgrade actually reduced monthly cost % financing best buy incentivesgreat keep please received said unlike keep getting cancelled confirmationnew iphone - droid - trying navigate everything challenge - issues group texts 'm receiving - shut phone restarted texts still show upi waited month entering review-very pleased iphone happy service data transferred within minutes running > ’ upgrade phone frequently went big jump appears need probably lot could learn ’ features hooked home button loss makes frame little smaller phone seems much lighter ‘ swiping ’ definitely takes getting used toproduct follows design functionality previous generations iphonesthis phone great upgrade son slow iphone three years battery sure wish apple would allow easy battery changesnew phones work great best device moneydaughter needed new phone xr working bit smaller liked memory disappointed charging block included apple issue otherwise working well set store greati upgraded scratch head ’ upgrading along way night daygreat value ’ pass carrier deals moms old samsung galaxy personally pro iphone kind guy $ ’ beat phone offersafter seeing product realized wanted bigger size phone great useful need something little betteralways love apple products phone disappoint color gorgeous display crisp clear great upgrades camera wellbest phone everrrrrrrrrrrr ’ perfect apple grow phone flawseasy use much larger old phoneas always apple products exceed expectations ’ committed apple family line productsneeded upgrade went iphone price reasonable really like colorthe phone real nice associate transaction goodpurchased phone son said awesome way better iphone xr previously usingbest phones really appreciate new style old styleapple makes best cellphone market hands downas expected high-quality product transitioned seamlesslyi love new iphone always anthoid phones happy switched applethe ok liking apple changed everything buy new plug use usb cords plenty thought would go phonei previously samsung galaxy time new phone phone acceptable quality may slightly betterabsolutely love took bit setup box apple makes super easyupgraded son iphone iphone hood yr oldphone fine purchase process disaster salesman distracted interrupted former clients sales people never full attention apparently entered erroneous information leading follow visit different store never againonly purchase iphones @ best buy quality knowledge servicei love new phone takes little time get used differences old one oneawesome phone replaced iphone x great deal excellent qualityi love iphone bought ’ iphone stock still happy itreally fast coming iphone next phone iphone got iphone wife loves itvery pleased functionality size weight phonealways buy iphones never disappointed phonethe iphone experience straightforward reliable ostook little time getting used new phone love itproduct better past models better camera memory longer battery life better storage faster processorthe phone better speakers phone quality screen outstandinggreat produ ...

# %% [markdown]
# ### we can think about some keyword we can replace in this part
# #### Many times terms need to be replaced for other terms
# ### E.g., wi-fi, wifi, internet, wi fi
# #### In this example: tub by bathtub
# #### newText = (" "+newText+" ").replace(" tub "," bathtub ")
# #### print("Text the replacements:\n", newText)

# %%
# lemmatize the text - reduce terms to their origin
from nltk.stem.wordnet import WordNetLemmatizer

# %%
# We are using the tokanized text
lem = WordNetLemmatizer()
lemmatizedText= []
for t in cleanedText:
    lemWord = lem.lemmatize(t)
    lemmatizedText.append(lemWord)
print("Lemmatized text :\n",lemmatizedText)
# Not that much of a difference - let's see steming
# Out:
# Lemmatized text :
#  ['apple', 'make', 'best', 'cellphone', 'market', 'hand', 'downease', 'use', 'good', 'battery', 'life', 'gb', 'fit', 'finelove', 'work', 'great', 'red', 'color', 'gorgeous', 'iphone', 'color', 'everbeen', 'long', 'time', 'iphone', 'user', 'awesome', 'phone', 'full', 'size', 'screen', 'much', 'faster', 'many', 'way', 'customize', 'love', 'itmy', 'wife', 'dropped', 'phone', 'right', 'apple', 'protect', 'plan', 'expiredliked', 'color', 'otterbox', 'cover', 'colorthe', 'perfect', 'iphone', 'thing', 'amazing', 'anyone', 'family', 'kid', 'grandma', 'anyone', 'else', 'super', 'powerful', 'run', 'business', 'itwe', 'going', 'purchase', 'iphones', 'verizon', 'stopped', 'best', 'buy', '%', 'finance', 'best', 'buy', 'person', 'excellent', 'knowledge', 'started', 'finish', 'assisted', 'way', 'husband', 'much', 'satisfied', 'glad', 'shop', 'best', 'buyso', 'far', 'good', 'used', 'android', 'since', 'got', 'cellphone', 'year', 'ago', 'difference', 'easy', 'learn', 'use', 'senior', 'population', 'member', 'highly', 'recommend', 'afraid', 'smaller', 'keyboard', 'problemthe', 'phone', 'pretty', '-', "n't", 'like', 'shutting', 'screen', 'side', 'button', 'side', 'get', 'pressed', 'together', 'trying', 'press', 'one', 'picture', 'taken', '-', 'also', 'button', 'silence', 'phone', 'hard', 'finger', 'reach', 'move', 'itlong', 'overdue', 'upgrade', 'iphone', 'totally', 'worth', 'especially', 'adding', 'verizon', 'plan', 'upgrade', 'actually', 'reduced', 'monthly', 'cost', '%', 'financing', 'best', 'buy', 'incentivesgreat', 'keep', 'please', 'received', 'said', 'unlike', 'keep', 'getting', 'cancelled', 'confirmationnew', 'iphone', '-', 'droid', '-', 'trying', 'navigate', 'everything', 'challenge', '-', 'issue', 'group', 'text', "'m", 'receiving', '-', 'shut', 'phone', 'restarted', 'text', 'still', 'show', 'upi', 'waited', 'month', 'entering', 'review-very', 'pleased', 'iphone', 'happy', 'service', 'data', 'transferred', 'within', 'minute', 'running', '>', '’', 'upgrade', 'phone', 'frequently', 'went', 'big', 'jump', 'appears', 'need', 'probably', 'lot', 'could', 'learn', '’', 'feature', 'hooked', 'home', 'button', 'loss', 'make', 'frame', 'little', 'smaller', 'phone', 'seems', 'much', 'lighter', '‘', 'swiping', '’', 'definitely', 'take', 'getting', 'used', 'toproduct', 'follows', 'design', 'functionality', 'previous', 'generation', 'iphonesthis', 'phone', 'great', 'upgrade', 'son', 'slow', 'iphone', 'three', 'year', 'battery', 'sure', 'wish', 'apple', 'would', 'allow', 'easy', 'battery', 'changesnew', 'phone', 'work', 'great', 'best', 'device', 'moneydaughter', 'needed', 'new', 'phone', 'xr', 'working', 'bit', 'smaller', 'liked', 'memory', 'disappointed', 'charging', 'block', 'included', 'apple', 'issue', 'otherwise', 'working', 'well', 'set', 'store', 'greati', 'upgraded', 'scratch', 'head', '’', 'upgrading', 'along', 'way', 'night', 'daygreat', 'value', '’', 'pas', 'carrier', 'deal', 'mom', 'old', 'samsung', 'galaxy', 'personally', 'pro', 'iphone', 'kind', 'guy', '$', '’', 'beat', 'phone', 'offersafter', 'seeing', 'product', 'realized', 'wanted', 'bigger', 'size', 'phone', 'great', 'useful', 'need', 'something', 'little', 'betteralways', 'love', 'apple', 'product', 'phone', 'disappoint', 'color', 'gorgeous', 'display', 'crisp', 'clear', 'great', 'upgrade', 'camera', 'wellbest', 'phone', 'everrrrrrrrrrrr', '’', 'perfect', 'apple', 'grow', 'phone', 'flawseasy', 'use', 'much', 'larger', 'old', 'phoneas', 'always', 'apple', 'product', 'exceed', 'expectation', '’', 'committed', 'apple', 'family', 'line', 'productsneeded', 'upgrade', 'went', 'iphone', 'price', 'reasonable', 'really', 'like', 'colorthe', 'phone', 'real', 'nice', 'associate', 'transaction', 'goodpurchased', 'phone', 'son', 'said', 'awesome', 'way', 'better', 'iphone', 'xr', 'previously', 'usingbest', 'phone', 'really', 'appreciate', 'new', 'style', 'old', 'styleapple', 'make', 'best', 'cellphone', 'market', 'hand', 'downas', 'expected', 'high-quality', 'product', 'transitioned', 'seamless ...

# %%
# Check the differences after this
# Verbs like "stayed -> stay" or "arranged -> arrang"
stem = PorterStemmer()
stemmedText = []
for t in cleanedText:
    stemmedWord = stem.stem(t)
    stemmedText.append(stemmedWord)
print("Stemmed text :\n",stemmedText)
# Out:
# Stemmed text :
#  ['appl', 'make', 'best', 'cellphon', 'market', 'hand', 'downeas', 'use', 'good', 'batteri', 'life', 'gb', 'fit', 'finelov', 'work', 'great', 'red', 'color', 'gorgeou', 'iphon', 'color', 'everbeen', 'long', 'time', 'iphon', 'user', 'awesom', 'phone', 'full', 'size', 'screen', 'much', 'faster', 'mani', 'way', 'custom', 'love', 'itmi', 'wife', 'drop', 'phone', 'right', 'appl', 'protect', 'plan', 'expiredlik', 'color', 'otterbox', 'cover', 'colorth', 'perfect', 'iphon', 'thing', 'amaz', 'anyon', 'famili', 'kid', 'grandma', 'anyon', 'els', 'super', 'power', 'run', 'busi', 'itw', 'go', 'purchas', 'iphon', 'verizon', 'stop', 'best', 'buy', '%', 'financ', 'best', 'buy', 'person', 'excel', 'knowledg', 'start', 'finish', 'assist', 'way', 'husband', 'much', 'satisfi', 'glad', 'shop', 'best', 'buyso', 'far', 'good', 'use', 'android', 'sinc', 'got', 'cellphon', 'year', 'ago', 'differ', 'easi', 'learn', 'use', 'senior', 'popul', 'member', 'highli', 'recommend', 'afraid', 'smaller', 'keyboard', 'problemth', 'phone', 'pretti', '-', "n't", 'like', 'shut', 'screen', 'side', 'button', 'side', 'get', 'press', 'togeth', 'tri', 'press', 'one', 'pictur', 'taken', '-', 'also', 'button', 'silenc', 'phone', 'hard', 'finger', 'reach', 'move', 'itlong', 'overdu', 'upgrad', 'iphon', 'total', 'worth', 'especi', 'ad', 'verizon', 'plan', 'upgrad', 'actual', 'reduc', 'monthli', 'cost', '%', 'financ', 'best', 'buy', 'incentivesgreat', 'keep', 'pleas', 'receiv', 'said', 'unlik', 'keep', 'get', 'cancel', 'confirmationnew', 'iphon', '-', 'droid', '-', 'tri', 'navig', 'everyth', 'challeng', '-', 'issu', 'group', 'text', "'m", 'receiv', '-', 'shut', 'phone', 'restart', 'text', 'still', 'show', 'upi', 'wait', 'month', 'enter', 'review-veri', 'pleas', 'iphon', 'happi', 'servic', 'data', 'transfer', 'within', 'minut', 'run', '>', '’', 'upgrad', 'phone', 'frequent', 'went', 'big', 'jump', 'appear', 'need', 'probabl', 'lot', 'could', 'learn', '’', 'featur', 'hook', 'home', 'button', 'loss', 'make', 'frame', 'littl', 'smaller', 'phone', 'seem', 'much', 'lighter', '‘', 'swipe', '’', 'definit', 'take', 'get', 'use', 'toproduct', 'follow', 'design', 'function', 'previou', 'gener', 'iphonesthi', 'phone', 'great', 'upgrad', 'son', 'slow', 'iphon', 'three', 'year', 'batteri', 'sure', 'wish', 'appl', 'would', 'allow', 'easi', 'batteri', 'changesnew', 'phone', 'work', 'great', 'best', 'devic', 'moneydaught', 'need', 'new', 'phone', 'xr', 'work', 'bit', 'smaller', 'like', 'memori', 'disappoint', 'charg', 'block', 'includ', 'appl', 'issu', 'otherwis', 'work', 'well', 'set', 'store', 'greati', 'upgrad', 'scratch', 'head', '’', 'upgrad', 'along', 'way', 'night', 'daygreat', 'valu', '’', 'pass', 'carrier', 'deal', 'mom', 'old', 'samsung', 'galaxi', 'person', 'pro', 'iphon', 'kind', 'guy', '$', '’', 'beat', 'phone', 'offersaft', 'see', 'product', 'realiz', 'want', 'bigger', 'size', 'phone', 'great', 'use', 'need', 'someth', 'littl', 'betteralway', 'love', 'appl', 'product', 'phone', 'disappoint', 'color', 'gorgeou', 'display', 'crisp', 'clear', 'great', 'upgrad', 'camera', 'wellbest', 'phone', 'everrrrrrrrrrrr', '’', 'perfect', 'appl', 'grow', 'phone', 'flawseasi', 'use', 'much', 'larger', 'old', 'phonea', 'alway', 'appl', 'product', 'exceed', 'expect', '’', 'commit', 'appl', 'famili', 'line', 'productsneed', 'upgrad', 'went', 'iphon', 'price', 'reason', 'realli', 'like', 'colorth', 'phone', 'real', 'nice', 'associ', 'transact', 'goodpurchas', 'phone', 'son', 'said', 'awesom', 'way', 'better', 'iphon', 'xr', 'previous', 'usingbest', 'phone', 'realli', 'appreci', 'new', 'style', 'old', 'styleappl', 'make', 'best', 'cellphon', 'market', 'hand', 'downa', 'expect', 'high-qual', 'product', 'transit', 'seamlesslyi', 'love', 'new', 'iphon', 'alway', 'anthoid', 'phone', 'happi', 'switch', 'appleth', 'ok', 'like', 'appl', 'chang', 'everyth', 'buy', 'new', 'plug', 'use', 'usb', 'cord', 'plenti', 'thought', 'would', 'go', 'phonei', 'previous', 'samsung', 'galaxi', 'time', 'new', 'phone', 'phone ...
